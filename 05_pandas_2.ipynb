# %%
import warnings
warnings.filterwarnings('ignore')
from IPython.display import Image
import numpy as np
import pandas as pd

# %% [markdown]
# 판다스 데이터프레임과 시리즈
# 데이터프레임과 시리즈는 딕셔너리와 비슷하지만 데이터를 다루는데 더 특화되어 있다.
# 리스트와 딕셔너리는 많은 양의 데이터를 저장하거나 조작할 수 있는 메소드가 많지 않은 반면에 판다스의 데이터프레임과 시리즈는
# 많은 양의 데이터를 저장할 수 있을 뿐만 아니라 스프레드시트 프로그램을 사용하는 것 처럼 행과 열 단위로 데이터를 조작할 수 있는
# 다양한 속성과 함수를 제공한다.

# %%
# 시리즈 만들기
s = pd.Series(['banana',2000])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    banana
# 1      2000
# dtype: object

# %%
s = pd.Series(['홍길동','이몽룡'])
print(s)

# 시리즈를 생성할 때 문자열을 인덱스로 지정할 수 있다.
# 문자열을 인덱스로 지정하려면 Series() 함수의 index 속성에 인덱스로 사용하려는 문자열을 리스트에 담아서 전달하면 된다.
s = pd.Series(['홍길동','이몽룡'],index=['도적','공무원'])
print(s)
# Out:
# 0    홍길동
# 1    이몽룡
# dtype: object
# 도적     홍길동
# 공무원    이몽룡
# dtype: object

# %% [markdown]
# 데이터프레임 만들기

# %%
# 데이터프레임을 만들기 위해서는 딕셔너리를 DataFrame() 함수의 인수로 전달하면 된다.
df = pd.DataFrame({
    # 'key':[value,value, ...] # key는 데이터프레임의 열 이름이 되고 value가 데이터가 된다.
    'Name':['홍길동','임꺽정'], 'Job':['도둑','공무원'], 'Born':['1920-04-20','1875-06-10'],
    'Died' : ['1957-08-20','1930-12-10'], 'Age':[37,60]
}, index=['홍길동','임꺽정'],
    columns=['Job','Born','Died','4'] # -> 4번은 Age로 바꾸면 컬럼이 생긴다.
)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Job        Born        Died    4
# 홍길동   도둑  1920-04-20  1957-08-20  NaN
# 임꺽정  공무원  1875-06-10  1930-12-10  NaN

# %% [markdown]
# 시리즈 다루기

# %%
# 데이터프레임에서 시리즈를 선택하려면 loc 속성에 열 이름을 전달하거나 iloc 속성에 인덱스를 전달하면 된다.
row = df.loc['임꺽정']
row
# Out:
# Job            공무원
# Born    1875-06-10
# Died    1930-12-10
# 4              NaN
# Name: 임꺽정, dtype: object

# %% [markdown]
# index, values 속성과 keys() 함수

# %%
# index 속성은 시리즈의 인덱스를 얻어온다.
print(type(row.index))
print(row.index)
print('='*50)
# values 속성은 시리즈의 데이터를 얻어온다.
print(type(row.values))
print(row.values)
print('='*50)
# keys() 함수는 index 속성과 같이 시리즈의 인덱스를 얻어온다.
print(type(row.keys()))
print(row.keys())
print('='*50)
# index 속성의 첫 번째 값 추출하기
print(row.index[0])
print(row.keys()[1])
# values 속성의 첫 번째 값 추출하기
print(row.values[0])
# Out:
# <class 'pandas.core.indexes.base.Index'>
# Index(['Job', 'Born', 'Died', '4'], dtype='object')
# ...
# <class 'numpy.ndarray'>
# ['공무원' '1875-06-10' '1930-12-10' nan]
# ...
# <class 'pandas.core.indexes.base.Index'>
# Index(['Job', 'Born', 'Died', '4'], dtype='object')
# ...
# Job
# Born
# 공무원

# %% [markdown]
# 시리즈 기초 통계 함수

# %%
scientists = pd.read_csv('data/scientists.csv')
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
aget = scientists['Age']
print(aget)

print('max ={}'.format(ages.max()))
print('min ={}'.format(ages.min()))
print('sum ={}'.format(ages.sum()))
print('mean ={}'.format(ages.mean()))
print('count ={}'.format(ages.count()))
print('std ={}'.format(ages.std())) # -> 표준편차
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64
# max =90
# min =61
# sum =294
# mean =73.5
# count =4
# std =12.871156384205214

# %% [markdown]
# 브로드 캐스팅

# %%
# 평균 나이보다 나이가 많은 사람의 나이 데이터를 추출한다.
age=scientists['Age'] > aget.mean()
scientists[scientists['Age']>aget.mean()]
ages=scientists.loc[age,'Age']
print(ages)
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
# 같은 길이의 벡터로 연산을 하면 결과값으로 같은 길이의 벡터가 출력된다.
# 벡터와 스칼라 값을 연산하면 벡터 각각의 값에 스칼라 값이 연산된 결과가 출력된다.

# %%
print(pd.Series([1,100]))
# 길이가 서로 다른 벡터를 연산하면 같은 인덱스를 가지는 값만 계산된다.
# pd.Series([1,100]) 의 0 , 1 인덱스만 계산되고 나머지는 계산할 수 없으므로 누락값(NaN, 결측치)
# 여기 영상보고 다시 너무 이상하게 나옴
print(ages + pd.Series([1,100])))
# Out:
#   File "<ipython-input-33-75fc13aaf53d>", line 4
#     print(ages + pd.Series([1,100])))
#                                     ^
# SyntaxError: invalid syntax

# %%
print(aget)
# sort_index() 함수는 데이터를 정렬하는 것이 아니고 인덱스를 정렬한다.
# ascending 옵션을 생략하면 True가 기본값으로 사용되며 오름차순 정렬
# 내림차순으로 하고 싶으면 False로 지정
rev_ages = aget.sort_index(ascending=False) # 별도의 설정이 없으면 오름차순
print(rev_ages)
# sort_values() 함수는 데이터 자체를 정렬한다.
rev_ages = aget.sort_values()
print(rev_ages)
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64
# 7    77
# 6    41
# 5    45
# 4    56
# 3    66
# 2    90
# 1    61
# 0    37
# Name: Age, dtype: int64
# 0    37
# 6    41
# 5    45
# 4    56
# 1    61
# 3    66
# 7    77
# 2    90
# Name: Age, dtype: int64

# %%
print(aget)
rev_ages = aget.sort_index(ascending=False)
print(rev_ages)
# 벡터와 벡터의 연산은 같은 인덱스를 가지는 값끼리 연산을 수행하기 때문에 aget + rev_ages 와 aget * 2는 같은 결과가 계산된다.
for age in aget + rev_ages:
    print('{0:4d}'.format(age),end=' ')
print()
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64
# 7    77
# 6    41
# 5    45
# 4    56
# 3    66
# 2    90
# 1    61
# 0    37
# Name: Age, dtype: int64
#   74  122  180  132  112   90   82  154

# %% [markdown]
# 데이터프레임도 시리즈와 마찬가지로 브로드캐스팅과 인덱싱을 할 수 있다.

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
scientists[scientists['Age']>scientists['Age'].mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
# 시리즈에 스칼라 연산을 적용할 때 모든 요소에 스칼라를 적용해서 연산이 실행된 것 처럼 데이터프레임도 마찬가지로 
# 데이터프레임에 2를 곱하면 문자열 데이터는 문자열이 2회 반복되고, 숫자데이터는 2를 곱한 숫자가 된다.
scientists * 2
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %% [markdown]
# 데이터프레임 열의 자료형 바꾸기

# %%
scientists.dtypes# 혹은 info
# Out:
# <bound method DataFrame.info of                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician>

# %%
# 날짜를 문자열 형태로 저장한 데이터는 날짜 및 시간관련 작업을 할 수 있도록 to_datetime() 함수로 datetime 자료형으로
# 바꿔주는 것이 좋다.
# pd.to_datetime(시리즈, format='%Y-%m-%d'), format 속성 생략시 ' '%Y-%m-%d '가 기본 서식으로 적용된다.
born_datetime = pd.to_datetime(scientists['Born'])
print(born_datetime)
died_datetime = pd.to_datetime(scientists['Died'])
print(died_datetime)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]
# 0   1958-04-16
# 1   1937-10-16
# 2   1910-08-13
# 3   1934-07-04
# 4   1964-04-14
# 5   1858-06-16
# 6   1954-06-07
# 7   1855-02-23
# Name: Died, dtype: datetime64[ns]

# %% [markdown]
# 파이썬의 strftime() 함수로 날짜 서식을 지정할 때 사용하는 날짜 서식문자
# %Y => 년도 4자리, %y => 년도 2자리
# %m => 원(숫자), %B => 월(영어, 전체), %b 또는 %h => 월(영어, 3글자)
# %d => 일, %A => 요일(전체), %a => 요일(3글자)
# %H => 시간(24시간), %I => 시각(12시간), %M => 분, %S => 초, %p => AM/PM, %f => 마이크로초

# %%
# dtypes 속성이나 info() 함수를 사용하면 시리즈 또는 데이터프레임에 저장된 데이터 타입을 얻어올 수 있다.
# 이전에 쓰던 print(type()) 이건 파이썬꺼 이기 때문에 판다스의 데이터프레임에는 잘 안맞는다. -> seies인지 dataframe인지 뭐 이정도만 나옴
print(type(scientists['Born']))
print(scientists['Born'].dtypes) # object => 파이썬의 문자열(str)은 판다스에서 object 타입이 된다.
print(scientists['Died'].dtypes)
# Out:
# <class 'pandas.core.series.Series'>
# object
# object

# %%
scientists = pd.read_csv('data/scientists.csv')

# %% [markdown]
# 파생 변수, 계산에 의한 변수

# %%
# datetime 타입으로 변경한 born_datetime, died_datetime를 scientists 데이터프레임에 열로 추가 한다.
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
# 데이터프레임['추가할 열 이름'] = 추가할 데이터
#scientists['born_df'] = born_datetime
#scientists['died_df'] = died_datetime
scientists['born_df'], scientists['died_df'] = born_datetime, died_datetime
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_df    died_df
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
# scientists['Died']-scientists['Born'] 문자열은 '-'연산을 할 수 없다.
# 그래서 연산을 위해 날짜 데이터로 변환해서 추가한 파생변수 born_df, died_df를 사용하면 얼마동안 살았는지 계산할 수 있다.
scientists['age_days_df']=scientists['died_df']-scientists['born_df']
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_df    died_df age_days_df
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12 1910-08-13  32964 days
# 3 1867-11-07 1934-07-04  24345 days
# 4 1907-05-27 1964-04-14  20777 days
# 5 1813-03-15 1858-06-16  16529 days
# 6 1912-06-23 1954-06-07  15324 days
# ...

# %% [markdown]
# 시리즈, 데이터프레임 열 섞기

# %%
import random as r
# shuffle() 함수는 데이터를 무작위로 섞어준다.
r.shuffle(scientists['Age']) # Age 부분만 데이터가 섞인데 다른데는 섞이지 않음
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   37        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   66               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   41             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   77           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   90  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   45       Mathematician
#
#      born_df    died_df age_days_df
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12 1910-08-13  32964 days
# 3 1867-11-07 1934-07-04  24345 days
# 4 1907-05-27 1964-04-14  20777 days
# 5 1813-03-15 1858-06-16  16529 days
# 6 1912-06-23 1954-06-07  15324 days
# ...

# %% [markdown]
# 데이터프레임 열 삭제하기

# %%
# drop() 함수는 데이터프레임의 열을 삭제한다.
# drop([삭제할 열 이름], axis = 1), 삭제할 열이 2개 이상일 경우 리스트에 넣어줘야 한다.
# drop() 함수는 axis =0이 기본값이고, axis=0으로 지정하면 행을 제거하려 하기 때문에 에러가 발생되므로 반드시 1로 지정
scientists_dropped = scientists.drop(['Born','Died'],axis=1)
scientists_dropped
# Out:
#                    Name  Age          Occupation    born_df    died_df  \
# 0     Rosaline Franklin   61             Chemist 1920-07-25 1958-04-16
# 1        William Gosset   37        Statistician 1876-06-13 1937-10-16
# 2  Florence Nightingale   66               Nurse 1820-05-12 1910-08-13
# 3           Marie Curie   41             Chemist 1867-11-07 1934-07-04
# 4         Rachel Carson   77           Biologist 1907-05-27 1964-04-14
# 5             John Snow   56           Physician 1813-03-15 1858-06-16
# 6           Alan Turing   90  Computer Scientist 1912-06-23 1954-06-07
# 7          Johann Gauss   45       Mathematician 1777-04-30 1855-02-23
#
#   age_days_df
# 0  13779 days
# 1  22404 days
# 2  32964 days
# 3  24345 days
# 4  20777 days
# 5  16529 days
# 6  15324 days
# 7  28422 days

# %% [markdown]
# 데이터를 피클, csv, tsv 파일로 저장하고 불러오기

# %%
names = scientists['Name']
print(names)
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
# 피클은 데이터를 바이너리 형태로 직렬화한 오브젝트를 저장하는 방법으로 데이터를 오래 보관한다는 뜻으로 
# 피클이라는 이름이 붙여진 것이다.
# 피클로 저장하면 스프레드시트보다 더 작은 용량으로 데이터를 저장할 수 있다.
# 시리즈를 피클로 저장하려면 to_pickle() 함수를 사용한다.
names.to_pickle('./output/scientists_name_series.pickle')

# %%
# 피클은 바이너리 형태의 오브젝트이기 때문에 저장된 피클을 데이터 편집기와 같은 프로그램에서 열면 이상한 문자가 나타난다.
# 피클을 읽어들이려면 read_pickle() 함수를 사용한다.
scientists_name_series_pickle = pd.read_pickle('./output/scientists_name_series.pickle')
scientists_name_series_pickle
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
scientists.to_pickle('./output/scientists_df.pickle')

# %%
scientists_pickle = pd.read_pickle('./output/scientists_df.pickle')
scientists_pickle
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   37        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   66               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   41             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   77           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   90  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   45       Mathematician
#
#      born_df    died_df age_days_df
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12 1910-08-13  32964 days
# 3 1867-11-07 1934-07-04  24345 days
# 4 1907-05-27 1964-04-14  20777 days
# 5 1813-03-15 1858-06-16  16529 days
# 6 1912-06-23 1954-06-07  15324 days
# ...

# %%
# to_csv() 함수로 시리즈와 데이터프레임을 텍스트 파일(csv, tsv) 파일로 저장 할 수 있다.
# 기본값이 csv로 설정되어있기 때문에 tsv 파일로 저장하려면 확장명에 'tsv'를 지정하고 sep 속성에 '\t'를 지정해야 한다.
names.to_csv('./output/scientists_name_seies.csv')
names.to_csv('./output/scientists_name_seies.tsv',sep='\t')
scientists.to_csv('./output/scientists_df.csv')
